# %% [markdown]
# # TUGAS MINGGU KEENAM (MATA KULIAH ALGORITMA DAN STRUKTUR DATA)

# %% [markdown]
# # 5.21 PANDAS
# Pandas merupakan Library pada Python yang digunakan pada data analisis. Tahap pertama perlu dilakukan pemanggilan Library seperti berikut ini:

# %%
import pandas as pd

# %% [markdown]
# Berikut contoh latihannya:

# %% [markdown]
# # 5.21.1 Membaca File Data pada Pandas

# %% [markdown]
# # Memanggil Pandas Melalui Link

# %%
#latihan 1

#memanggil data berbentuk csv melalui link
data_csv = pd.read_csv('https://raw.githubusercontent.com/imdwipayana/DATA/main/Bunga%20Iris/bunga_iris.csv')
print(data_csv)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
#latihan 2

#memanggil kembali data berbentuk csv
data_csv
# Out:
#      sepal length (cm)  petal length (cm) petal width (cm)  sepal
# 0                  5.1                1.4             none    1.6
# 1                  4.9                1.4             none    1.6
# 2                  4.7                1.3             none    1.5
# 3                  4.6                1.5             none    1.7
# 4                  5.0                1.4             none    1.6
# ..                 ...                ...              ...    ...
# 145                6.7                5.2              2.3    7.5
# 146                6.3                5.0              1.9    6.9
# 147                6.5                5.2              2.0    7.2
# 148                6.2                5.4              2.3    7.7
# 149                5.9                5.1              1.8    6.9
#
# [150 rows x 4 columns]

# %% [markdown]
# # Memanggil Pandas melalui Folder

# %%
#latihan 1

#sebelum memanggil data, pastikan nama file data yang disimpan dalam folder yang ingin dipanggil
#berikut cara memanggil data berbentuk csv yang disimpan dalam folder
data_csv = pd.read_csv('bunga_iris.csv')
print(data_csv)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# # 5.21.2 Properti pada Pandas
# Pandas memiliki beberapa properti untuk memudahkan melakukan observasi awal tentang data yang baru dipanggil.

# %% [markdown]
# Berikut latihan untuk data csv:

# %%
#latihan 1

#memanggil empat data teratas yang berbentuk csv, dengan cara:
print(data_csv.head(4))
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2

# %%
#latihan 2

#menentukan data (kolom) apa saja yang terdapat dalam file data csv
print(data_csv.columns)
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)'],
#       dtype='object')

# %%
#latihan 3

#mencetak data "sepal lenght (cm)" dari data csv
print(data_csv['sepal length (cm)'])
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal length (cm), Length: 150, dtype: float64

# %%
#latihan 4

#mencetak data "sepal length (cm)" pada urutan ke 2 pada data csv
print(data_csv['sepal length (cm)'][2])
# Out:
# 4.7

# %%
#latihan 5

#mencetak data "sepal length (cm)" pada urutan ke 0 sampai sebelum ke 5 pada data csv
print(data_csv["sepal length (cm)"][0:5])
# Out:
# 0    5.1
# 1    4.9
# 2    4.7
# 3    4.6
# 4    5.0
# Name: sepal length (cm), dtype: float64

# %%
#latihan 6

#mencetak data "sepal length (cm)" beserta "sepal width (cm)" dari urutan ke 0 sampai sebelum ke 5 pada data csv
print(data_csv[['sepal length (cm)','sepal width (cm)']][0:5])
# Out:
#    sepal length (cm)  sepal width (cm)
# 0                5.1               3.5
# 1                4.9               3.0
# 2                4.7               3.2
# 3                4.6               3.1
# 4                5.0               3.6

# %%
#latihan 7

#mencetak data lengkap pada urutan ke 2 dari data csv
print(data_csv.iloc[2])
# Out:
# sepal length (cm)    4.7
# sepal width (cm)     3.2
# petal length (cm)    1.3
# petal width (cm)     0.2
# Name: 2, dtype: float64

# %%
#latihan 8

#mencetak data lengkap dari urutan ke 0 sampai sebelum 6 pada data csv
print(data_csv.iloc[0:6])
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
# 5                5.4               3.9                1.7               0.4

# %%
#latihan 9

#menampilkan data sesuai dengan perintah 
#menampilkan data sepal length dengan ketentuan hanya data yang 4.4 cm saja yang diambil
print(data_csv.loc[data_csv['sepal length (cm)']==4.4])
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 8                 4.4               2.9                1.4               0.2
# 38                4.4               3.0                1.3               0.2
# 42                4.4               3.2                1.3               0.2

# %% [markdown]
# # 5.21.3 Mengurutkan Data pada Pandas
# Data yang dipanggil dapat diurutkan mulai dari tinggi ke rendah (atau dari rendah ke tinggi) untuk data berupa angka, sedangkan data berupa string akan diurutkan berdasarkan urutan abjad.
#
# Berikut contoh latihannya:

# %%
#latihan 1

#berikut latihan mengurutkan data dari urutan rendah ke tinggi berdasarkan dari data petal length (cm)
data_csv.sort_values('petal length (cm)')
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 22                 4.6               3.6                1.0               0.2
# 13                 4.3               3.0                1.1               0.1
# 14                 5.8               4.0                1.2               0.2
# 35                 5.0               3.2                1.2               0.2
# 36                 5.5               3.5                1.3               0.2
# ..                 ...               ...                ...               ...
# 131                7.9               3.8                6.4               2.0
# 105                7.6               3.0                6.6               2.1
# 117                7.7               3.8                6.7               2.2
# 122                7.7               2.8                6.7               2.0
# 118                7.7               2.6                6.9               2.3
#
# [150 rows x 4 columns]

# %%
#latihan 2

#berikut latihan mengurutkan data dari urutan tinggi ke rendah berdasarkan dari data petal length (cm)
data_csv.sort_values('petal length (cm)', ascending=False)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 118                7.7               2.6                6.9               2.3
# 122                7.7               2.8                6.7               2.0
# 117                7.7               3.8                6.7               2.2
# 105                7.6               3.0                6.6               2.1
# 131                7.9               3.8                6.4               2.0
# ..                 ...               ...                ...               ...
# 16                 5.4               3.9                1.3               0.4
# 35                 5.0               3.2                1.2               0.2
# 14                 5.8               4.0                1.2               0.2
# 13                 4.3               3.0                1.1               0.1
# 22                 4.6               3.6                1.0               0.2
#
# [150 rows x 4 columns]

# %% [markdown]
# # 5.21.4 Mengubah Data pada Pandas
# Data yang telah dipanggil dapat dirubah sesuai dengan kebutuhan.
#
# Berikut contoh latihannya:

# %%
#latihan 1

#pada latihan ini, kita akan menghilangkan kolom "sepal width (cm)"
data_csv = data_csv.drop(columns = ['sepal width (cm)'])
print(data_csv)
# Out:
#      sepal length (cm)  petal length (cm)  petal width (cm)
# 0                  5.1                1.4               0.2
# 1                  4.9                1.4               0.2
# 2                  4.7                1.3               0.2
# 3                  4.6                1.5               0.2
# 4                  5.0                1.4               0.2
# ..                 ...                ...               ...
# 145                6.7                5.2               2.3
# 146                6.3                5.0               1.9
# 147                6.5                5.2               2.0
# 148                6.2                5.4               2.3
# 149                5.9                5.1               1.8
#
# [150 rows x 3 columns]

# %%
#latihan 2

#mengurutkan data petal length (cm) dan petal width (cm) dari data yang terendah ke data yang tertinggi
data_csv.sort_values(['petal length (cm)','petal width (cm)'])
# Out:
#      sepal length (cm)  petal length (cm)  petal width (cm)
# 22                 4.6                1.0               0.2
# 13                 4.3                1.1               0.1
# 14                 5.8                1.2               0.2
# 35                 5.0                1.2               0.2
# 2                  4.7                1.3               0.2
# ..                 ...                ...               ...
# 131                7.9                6.4               2.0
# 105                7.6                6.6               2.1
# 122                7.7                6.7               2.0
# 117                7.7                6.7               2.2
# 118                7.7                6.9               2.3
#
# [150 rows x 3 columns]

# %%
#latihan  3

#mengurutkan data petal length (cm) dan petal width (cm) dari data yang terendah ke data yang tertinggi
data_csv.sort_values(['petal length (cm)','petal width (cm)'])
# Out:
#      sepal length (cm)  petal length (cm)  petal width (cm)
# 22                 4.6                1.0               0.2
# 13                 4.3                1.1               0.1
# 14                 5.8                1.2               0.2
# 35                 5.0                1.2               0.2
# 2                  4.7                1.3               0.2
# ..                 ...                ...               ...
# 131                7.9                6.4               2.0
# 105                7.6                6.6               2.1
# 122                7.7                6.7               2.0
# 117                7.7                6.7               2.2
# 118                7.7                6.9               2.3
#
# [150 rows x 3 columns]

# %%
#latihan 4

#fungsi ini adalah memilih data dari dataframe
#dengan (:) memilih semua baris, dan (1:3) yaitu dari kolom 1 hingga kolom 3
#lalu sum(axis=1) adalah menggunakan sum untuk setiap baris
data_csv['sepal'] = data_csv.iloc[:,1:3].sum(axis=1)
print(data_csv)

#sehingga akan ditambahkan kolom baru yaitu sepal yang berisi hasil penjumlahan dari kedua kolom pada subset dataframe yg telah dipilih
# Out:
#      sepal length (cm)  petal length (cm)  petal width (cm)  sepal
# 0                  5.1                1.4               0.2    1.6
# 1                  4.9                1.4               0.2    1.6
# 2                  4.7                1.3               0.2    1.5
# 3                  4.6                1.5               0.2    1.7
# 4                  5.0                1.4               0.2    1.6
# ..                 ...                ...               ...    ...
# 145                6.7                5.2               2.3    7.5
# 146                6.3                5.0               1.9    6.9
# 147                6.5                5.2               2.0    7.2
# 148                6.2                5.4               2.3    7.7
# 149                5.9                5.1               1.8    6.9
#
# [150 rows x 4 columns]

# %%
#latihan 5

#mengubah isi kolom petal width yang berisi angka 0.2 menjadi none pada dataframe
data_csv['petal width (cm)'] = data_csv['petal width (cm)'].replace([0.2],'none')
print(data_csv)
# Out:
#      sepal length (cm)  petal length (cm) petal width (cm)  sepal
# 0                  5.1                1.4             none    1.6
# 1                  4.9                1.4             none    1.6
# 2                  4.7                1.3             none    1.5
# 3                  4.6                1.5             none    1.7
# 4                  5.0                1.4             none    1.6
# ..                 ...                ...              ...    ...
# 145                6.7                5.2              2.3    7.5
# 146                6.3                5.0              1.9    6.9
# 147                6.5                5.2              2.0    7.2
# 148                6.2                5.4              2.3    7.7
# 149                5.9                5.1              1.8    6.9
#
# [150 rows x 4 columns]

# %% [markdown]
# # 5.21.5 Menyimpan Data menggunakan Pandas

# %%
#latihan 1

#data otomatis tersimpan pada folder dengan nama file sesuai dengan string yang kita tulis
#index=false, artinya data tersebut tidak menggunakan index
data_csv.to_csv('bunga_iris.csv',index=False)

# %% [markdown]
# # 5.21.6 Menyaring Data menggunakan Pandas

# %%
#latihan 1

#menampilkan data petal length yang hanya berisi 1.4
data_csv.loc[data_csv['petal length (cm)'] == 1.4]
# Out:
#     sepal length (cm)  petal length (cm) petal width (cm)  sepal
# 0                 5.1                1.4             none    1.6
# 1                 4.9                1.4             none    1.6
# 4                 5.0                1.4             none    1.6
# 6                 4.6                1.4              0.3    1.7
# 8                 4.4                1.4             none    1.6
# 12                4.8                1.4              0.1    1.5
# 17                5.1                1.4              0.3    1.7
# 28                5.2                1.4             none    1.6
# 33                5.5                1.4             none    1.6
# 37                4.9                1.4              0.1    1.5
# 45                4.8                1.4              0.3    1.7
# 47                4.6                1.4             none    1.6
# 49                5.0                1.4             none    1.6

# %%
#latihan 2

#menampilkan data petal length yang hanya berisi 1.4 dan data petal width yang hanya berisi 0.3
data_csv.loc[(data_csv['petal length (cm)'] == 1.4) & (data_csv['petal width (cm)'] == 0.3)]
# Out:
#     sepal length (cm)  petal length (cm) petal width (cm)  sepal
# 6                 4.6                1.4              0.3    1.7
# 17                5.1                1.4              0.3    1.7
# 45                4.8                1.4              0.3    1.7

# %%
#latihan 3

#menampilkan data sepal length yang hanya berisi 4.9 dan data petal length yang hanya berisi 1.4 dengan data sepal lebih besar dari 1.4
data_csv.loc[(data_csv['sepal length (cm)'] == 4.9) & (data_csv['petal length (cm)'] == 1.4) & (data_csv['sepal'] > 1.4)]
# Out:
#     sepal length (cm)  petal length (cm) petal width (cm)  sepal
# 1                 4.9                1.4             none    1.6
# 37                4.9                1.4              0.1    1.5

# %%
#latihan 4

data_csv.loc[data_csv['petal width (cm)'].str.contains(3.0)]
#data ini error karna dataframe yang digunakan adalah tipe float sedangkan sintaks ini digunakan untuk data bertipe str
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12436\487712213.py in <module>
#       1 #latihan 4
#       2
# ----> 3 data_csv.loc[data_csv['petal width (cm)'].str.contains(3.0)]
#       4 #data ini error karna dataframe yang digunakan adalah tipe float sedangkan sintaks ini digunakan untuk data bertipe str
#
# ~\anaconda3\lib\site-packages\pandas\core\strings\accessor.py in wrapper(self, *args, **kwargs)
#     123                 )
#     124                 raise TypeError(msg)
# --> 125             return func(self, *args, **kwargs)
#     126
#     127         wrapper.__name__ = func_name
#
# ~\anaconda3\lib\site-packages\pandas\core\strings\accessor.py in contains(self, pat, case, flags, na, regex)
#    1212         dtype: bool
#    1213         """
# -> 1214         if regex and re.compile(pat).groups:
#    1215             warnings.warn(
# ...

# %%
import re

# %%
#latihan 5

data_csv.loc[data_csv['petal length (cm)'].str.contains(1.4|1.6, regex=True)]
#data ini error karna dataframe yang digunakan adalah tipe float sedangkan sintaks ini digunakan untuk data bertipe str
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12436\2232121736.py in <module>
# ----> 1 data_csv.loc[data_csv['petal length (cm)'].str.contains(1.4|1.6, regex=True)]
#       2 #data akan error karna dataframe yang digunakan adalah tipe float sdangkan sintaks ini digunakan untuk data bertipe str
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     180             # we're accessing the attribute of the class, i.e., Dataset.geo
#     181             return self._accessor
# --> 182         accessor_obj = self._accessor(obj)
# ...

# %% [markdown]
# # 5.21.7 Pengelompokan Data menggunakan Pandas

# %%
#latihan 1

#perintah mean digunakan untuk menghitung rata-rata dari keseluruhan data
data_csv.groupby(['petal length (cm)']).mean()
# Out:
#                    sepal length (cm)     sepal
# petal length (cm)
# 1.0                         4.600000  1.200000
# 1.1                         4.300000  1.200000
# 1.2                         5.400000  1.400000
# 1.3                         4.842857  1.557143
# 1.4                         4.915385  1.607692
# 1.5                         5.146154  1.738462
# 1.6                         4.914286  1.885714
# 1.7                         5.400000  2.050000
# 1.9                         4.950000  2.200000
# 3.0                         5.100000  4.100000
# 3.3                         4.950000  4.300000
# 3.5                         5.350000  4.500000
# 3.6                         5.600000  4.900000
# 3.7                         5.500000  4.700000
# 3.8                         5.500000  4.900000
# 3.9                         5.533333  5.133333
# 4.0                         5.780000  5.220000
# 4.1                         5.700000  5.300000
# 4.2                         5.725000  5.525000
# ...

# %%
#latihan 2

#perintah mean digunakan untuk menghitung rata-rata dari keseluruhan data, dengan mengurutkan dari data terendah ke data tertinggi
data_csv.groupby(['petal length (cm)']).mean().sort_values('petal length (cm)',ascending=True)
# Out:
#                    sepal length (cm)     sepal
# petal length (cm)
# 1.0                         4.600000  1.200000
# 1.1                         4.300000  1.200000
# 1.2                         5.400000  1.400000
# 1.3                         4.842857  1.557143
# 1.4                         4.915385  1.607692
# 1.5                         5.146154  1.738462
# 1.6                         4.914286  1.885714
# 1.7                         5.400000  2.050000
# 1.9                         4.950000  2.200000
# 3.0                         5.100000  4.100000
# 3.3                         4.950000  4.300000
# 3.5                         5.350000  4.500000
# 3.6                         5.600000  4.900000
# 3.7                         5.500000  4.700000
# 3.8                         5.500000  4.900000
# 3.9                         5.533333  5.133333
# 4.0                         5.780000  5.220000
# 4.1                         5.700000  5.300000
# 4.2                         5.725000  5.525000
# ...

# %%
#latihan 3

#perintah sum digunakan untuk menghitung jumlah dari keseluruhan nilai data
data_csv.groupby(['petal width (cm)']).sum()
# Out:
#                   sepal length (cm)  petal length (cm)  sepal
# petal width (cm)
# 0.1                            24.1                6.9    7.4
# 0.3                            34.8               10.0   12.1
# 0.4                            37.1               11.0   13.8
# 0.5                             5.1                1.7    2.2
# 0.6                             5.0                1.6    2.2
# 1.0                            37.9               25.4   32.4
# 1.1                            16.2               10.7   14.0
# 1.2                            28.9               21.2   27.2
# 1.3                            76.5               54.3   71.2
# 1.4                            50.6               37.1   48.3
# 1.5                            74.2               55.9   73.9
# 1.6                            25.5               20.1   26.5
# 1.7                            11.6                9.5   12.9
# 1.8                            76.8               64.0   85.6
# ...

# %%
#latihan 4

#perintah count digunakan untuk menghitung jumlah dari kemunculan data
data_csv.groupby(['petal width (cm)']).count()
# Out:
#                   sepal length (cm)  petal length (cm)  sepal
# petal width (cm)
# 0.1                               5                  5      5
# 0.3                               7                  7      7
# 0.4                               7                  7      7
# 0.5                               1                  1      1
# 0.6                               1                  1      1
# 1.0                               7                  7      7
# 1.1                               3                  3      3
# 1.2                               5                  5      5
# 1.3                              13                 13     13
# 1.4                               8                  8      8
# 1.5                              12                 12     12
# 1.6                               4                  4      4
# 1.7                               2                  2      2
# 1.8                              12                 12     12
# ...

# %% [markdown]
# # 5.22 MATPLOTLIB
# Matplotlib merupakan salah satu Library pada Python yang fungsi utamanya adalah dalam hal menggambarkan grafik, histogram dan berbagai jenis plot hasil dari pengolahan data menggunakan Library lainnya yaitu Pandas dan Numpy. Untuk itu penggunaan ketiga Library tersebut biasanya menjadi satu kesatuan. Untuk itu hal pertama yang perlu dilakukan adalah memanggil ketiga jenis Library tersebut seperti
#
# Berikut contoh latihannya:

# %%
#hal pertama yang dilakukan adalah memanggil Library
import matplotlib.pyplot as plt

# %% [markdown]
# # 5.22.1 Grafik sederhana dengan Matplotlib

# %%
#latihan 1 (Grafik Garis)

#pertama-tama kita tentukan dulu angka yang berada dalam variabel x dan y
x = [5,6,7,8]
y = [6,7,8,9]
#lalu kita menggunakan plt.plot(x,y) untuk meletakkan posisi titik di x dan y
plt.plot(x,y)

#selanjutnya kita bisa memberikan judul grafik tersebut menggunakan plt.title
plt.title('Grafik y = x + 1')
#kemudian kita memberikan keterangan pada sumbu x(horizontal) menggunakan plt.xlabel
plt.xlabel('X')
#dan memberikan keterangan pada sumbu y(vertikal) menggunakan plt.ylabel
plt.ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')

# %% [markdown]
# # 5.22.2 Properti Pembuatan Grafik dengan Matplotlib

# %%
#latihan 1 (Grafik Garis)

#pertama-tama kita tentukan dulu angka yang berada dalam variabel x dan y
y = [25, 30, 35, 40, 50]
x = [2010, 2011, 2012, 2013, 2014]
#lalu kita menggunakan plt.plot(x,y) untuk meletakkan posisi titik di x dan y
plt.plot(x,y)

#kemudian kita memberikan keterangan pada sumbu x(horizontal) menggunakan plt.xlabel
plt.xlabel('Tahun')
#dan memberikan keterangan pada sumbu y(vertikal) menggunakan plt.ylabel
plt.ylabel('Jumlah siswa')

#selanjutnya kita bisa memberikan judul grafik tersebut menggunakan plt.title
plt.title('Lulusan SMA Negeri 2 Mengwi')
#kemudian kita gunakan plt.grid untuk menampilkan garis grid
plt.grid(True)

#dan kita menggunakan plt.show untuk menampilkan grafik
plt.show()

# %%
#latihan 2 (Grafik Batang)

#pertama-tama kita tentukan dulu angka yang berada dalam variabel x dan y
x = [1, 2, 3, 4, 5]
y = [80, 90, 95, 85, 79]

#lalu kita gunakan fig, ax untuk menambahkan kolom figure dan axes pada sublplots()
fig, ax = plt.subplots()

#kemudian kita gunakan ax.bar untuk membuat output persegi
ax.bar(x, y, color= 'tan')

#lalu kita gunakan ax.set_title untuk membuat judul grafik
ax.set_title('Nilai Siswa Kelas A SMAN 2')
#lalu kita gunakan ax.set_ylabel untuk menamai garis vertikal dan ax.set_xlabel untuk menamai garis horizontal
ax.set_ylabel('Nilai')
ax.set_xlabel('Mata Pelajaran')
#lalu kita gunakan ax.set_xticks untuk memberikan nilai pada garis horizontal
ax.set_xticks(x)
#kemudian ada ax.set_xticklabels untuk menamai nilai yang diciptakan xticks
ax.set_xticklabels(("IPA", "IPS", "Matematika", "Bahasa Inggris", "Kesenian"))

#lalu terakhir kita gunakan plt.show untuk menampilkan grafik
plt.show()

# %%
#latihan 3 (Grafik/Diagram Lingkaran)

#pertama kita tentukan dulu isi label untuk setiap data
labels = ['Tidak Bekerja', 'Guru', 'Dokter', 'Pengusaha']
#kemudian kita gunakan quantity untuk menentukan kuantitas dari setiap label
quantity = [9, 5, 6, 15]
#setelah itu kita gunakan colors untuk menentukan warna nya
colors = ['grey', 'plum', 'lightcoral', 'aquamarine']

#lalu kita gunakan plt.title untuk membuat judul grafik
plt.title('Pekerjaan Orang Tua Siswa SMAN 2')
#lalu kita gunakan plt.pie merupakan fungsi untuk mengidentifikasi label, kuantitas, dan warna, shadow digunakan untuk memberikan efek bayangan, startangle=90 digunakan untuk membuat tabel pada nilai pertama senilai 90 derajat
plt.pie(quantity, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=90)

#setelah itu plt.axis untuk memberikan aspek rasio pada setiap nilai
plt.axis('equal')

#terakhir plt.show untuk menampilkan grafik
plt.show()

# %% [markdown]
# # 5.22.3 Histogram Sederhana dengan Matplotlib

# %%
#latihan 1

#pertama kita tentukan dulu isi label untuk setiap data
gender = ['Mahasiswa', 'Mahasiswi']
jumlah = [40, 43]

#gunakan plt.bar untuk menampilkan historam
plt.bar(gender, jumlah)
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# # 5.22.4 Properti Pembuatan Histogram dengan Matplotlib

# %%
#latihan 1

#pertama-tama kita tentukan dulu isi label untuk setiap data
penyanyi = ["Sarwendah", "Tiara", "Ziva"]
penggemar = [100,120,108]

plt.figure(figsize=(8,4))
#kemudian tentukan warna yang ingin digunakan
histogram = plt.bar(penyanyi,penggemar,color='grey')

#selanjutnya tentukan pola yang ingin digunakan setiap datanya
histogram[0].set_hatch('x')
histogram[1].set_hatch('/')
histogram[2].set_hatch('o')

#terakhir akan ditampilkan histogramnya
plt.show()

# %% [markdown]
# # Tambahan untuk Data Bunga Iris menggunakan Pandas dan Matplotlib

# %%
#hal pertama yang kita lakukan yaitu memanggil library pandas dan matplotib
import pandas as pd
import matplotlib.pyplot as plt

# %%
#latihan 1

#pertama-tama lakukan pemanggilan data dengan menggunakan metode .read_csv 
data_iris = pd.read_csv('bunga_iris.csv')

#kemudian kita gunakan kolom petal_length dari dataframe iris_data
petal_length = data_iris['petal length (cm)']

#selanjutnya kita membuat histogram dari data petal_length
plt.hist(petal_length, bins=150, color='black')
#Akan dibuat suatu plot histogram dari petal length
#bins adalah interval dari histogram yang akan dibuat

plt.xlabel('Petal Length (cm)')
#label sumbu x akan menunjukkan petal length 
plt.ylabel('Frekuensi')
#label sumbu y akan menunjukkan frekuensi nilai panjang kelopak dalam setiap interval (bin)
plt.title('Histogram Petal Length(cm)')
#dibuat judul dengan string "Histogram Petal Length(cm)"

#terakhir kita tampilkan histogramnya
plt.show()

# %%
#latihan 2

#pertama-tama kita lakukan pemanggilan data dengan menggunakan metode .read_csv
iris_data = pd.read_csv('bunga_iris.csv')

#Selanjutnya kita pilih kolom yang akan digunakan dalam gambar
#dalam latihan ini, dipilih kolom 'petal length (cm)' dan kolom 'petal width (cm)'
petal_length = iris_data['petal length (cm)']
petal_width = iris_data['petal width (cm)']

#selanjutnya, kita membuat scatter plot mengenai hubungan antara petal length dan petal width
plt.scatter(petal_length, petal_width)

plt.xlabel('Petal Length (cm)')
#digunakan label sumbu x untuk merepresentasikan label yang ingin ditambahkan pada sumbu x
plt.ylabel('Petal Width (cm )')
#digunakan label sumbu y untuk merepresentasikan label yang ingin ditambahkan pada sumbu y

plt.title('Scatter Plot dari Petal Length (cm) dan Petal Width (cm)')
#gunakan plt.title untuk menambahkan judul pada sactter plot dengan mengambil string Scatter Plot dari Petal Length (cm) dan Petal Width (cm)' sebagai argumen

#gunakan plt.show untuk menampilkan sactter plot
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
